# %%
print('Problem 1: I Love You, Tuple')
print()
# My favorite romance movies
# title, release year, runtime, tagline, main characters
romantic_movie1 = ("The Princess Bride", 1987, 98, "The story of a man and a woman who lived happily ever after.", ["Buttercup", "Westley", "Fezzik", "Inigo Montoya",
"Vizzini"])
romantic_movie2 = ("Groundhog Day", 1993, 101, "He's having the day of his life…over and over again.", ["Phil Connors"])
romantic_movie3 = ("Amélie", 2001, 122, "One person can change your life forever.",["Amélie Poulain", "Nino Quincampoix", "The Garden Gnome"])
#Here are my favorite romance movies:
#The Princess Bride (1987): The story of a man and a woman who lived happily ever after.
#Groundhog Day (1993): He's having the day of his life...over and over again.
#Amélie (2001): One person can change your life forever.


print('Option 1')
movie = "{} ({}) {}".format((romantic_movie1[0]), (romantic_movie1[1]), (romantic_movie1[3]))
print(movie)
movie = "{} ({}) {}".format((romantic_movie2[0]), (romantic_movie2[1]), (romantic_movie2[3]))
print(movie)
movie = "{} ({}) {}".format((romantic_movie3[0]), (romantic_movie3[1]), (romantic_movie3[3]))
print(movie)

print()

print('Option 2')
result =''
for movies in range(4):
    if movies == 2:
        continue
    else:
        if (type(romantic_movie1[movies])) == int:
            result += ' ('+str(romantic_movie1[movies])+') '
        else:
            result += str(romantic_movie1[movies])
print(result)
        
result =''
for movies in range(4):
    if movies == 2:
        continue
    else:
        if (type(romantic_movie2[movies])) == int:
            result += ' ('+str(romantic_movie2[movies])+') '
        else:
            result += str(romantic_movie2[movies])
print(result)

result =''
for movies in range(4):
    if movies == 2:
        continue
    else:
        if (type(romantic_movie3[movies])) == int:
            result += ' ('+str(romantic_movie3[movies])+') '
        else:
            result += str(romantic_movie3[movies])
print(result)
# Out:
# Problem 1: I Love You, Tuple
#
# Option 1
# The Princess Bride (1987) The story of a man and a woman who lived happily ever after.
# Groundhog Day (1993) He's having the day of his life…over and over again.
# Amélie (2001) One person can change your life forever.
#
# Option 2
# The Princess Bride (1987) The story of a man and a woman who lived happily ever after.
# Groundhog Day (1993) He's having the day of his life…over and over again.
# Amélie (2001) One person can change your life forever.

# %%
#Your boss tasks you with creating a company directory. Make a list called employees, which will
#contain one dictionary per person and include the keys name, age, department, phone, and salary.
#Once you have the list of dictionaries set up, loop through the list and print out the name,
#department, and phone number of each employee. Their age and salary should remain secret!

print('Problem 2: Friends, Colleagues, and Details')
print()
employee = {   'E0001': {  'Name': 'Ron Swanson',
                                'Age': 55,
                                'Dept':'Management',
                                'Phone':'555-1234',
                                'Salary': 1000 },
                 
                    'E0002': {  'Name': 'Leslie Knope',
                                'Age': 47,
                                'Dept':'Middle Management',
                                'Phone':'555-4321',
                                'Salary': 1350 },
                 
                    'E0003': {  'Name': 'Andy Dwyer',
                                'Age': 32,
                                'Dept':'Shoe Shining',
                                'Phone':'555-1122',
                                'Salary': 841 },
                 
                    'E0004': {  'Name': 'April Ludgate',
                                'Age': 29,
                                'Dept':'Administration',
                                'Phone':'555-3345',
                                'Salary': 700 },
                }

for key, value in employee.items():
    print('EmpID',"\t",':', key,)
    for detail, info in value.items():
        print(detail,"\t", ':',info)
    print()
print('---------------------------')

for key, emp in employee.items():
    print(employee[key]['Name'], 'in',employee[key]['Dept'], 'can be reached at', employee[key]['Phone'])
    print()
# Out:
# Problem 2: Friends, Colleagues, and Details
#
# EmpID 	 : E0001
# Name 	 : Ron Swanson
# Age 	 : 55
# Dept 	 : Management
# Phone 	 : 555-1234
# Salary 	 : 1000
#
# EmpID 	 : E0002
# Name 	 : Leslie Knope
# Age 	 : 47
# Dept 	 : Middle Management
# Phone 	 : 555-4321
# Salary 	 : 1350
#
# EmpID 	 : E0003
# Name 	 : Andy Dwyer
# Age 	 : 32
# Dept 	 : Shoe Shining
# Phone 	 : 555-1122
# Salary 	 : 841
#
# EmpID 	 : E0004
# Name 	 : April Ludgate
# Age 	 : 29
# Dept 	 : Administration
# Phone 	 : 555-3345
# Salary 	 : 700
#
# ---------------------------
# Ron Swanson in Management can be reached at 555-1234
#
# Leslie Knope in Middle Management can be reached at 555-4321
#
# Andy Dwyer in Shoe Shining can be reached at 555-1122
#
# April Ludgate in Administration can be reached at 555-3345
